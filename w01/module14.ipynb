# %% [markdown]
# ## Numpy Concepts

# %%
import numpy as np

# %%
a = [[1,2,3],[4,5,6],[5,6,7]]

# %%
a
# Out:
# [[1, 2, 3], [4, 5, 6], [5, 6, 7]]

# %%
b = np.array(a)
b
# Out:
# array([[1, 2, 3],
#        [4, 5, 6],
#        [5, 6, 7]])

# %%
b.T
# Out:
# array([[1, 4, 5],
#        [2, 5, 6],
#        [3, 6, 7]])

# %%
c = np.array([[1,2,3],[3,4,5],[4,5,6]])

# %%
c
# Out:
# array([[1, 2, 3],
#        [3, 4, 5],
#        [4, 5, 6]])

# %%
e = b.dot(c)
e
# Out:
# array([[19, 25, 31],
#        [43, 58, 73],
#        [51, 69, 87]])

# %%
b @ c
# Out:
# array([[19, 25, 31],
#        [43, 58, 73],
#        [51, 69, 87]])

# %%
f = np.where(e < 50, e, 10*e)
f
# Out:
# array([[ 19,  25,  31],
#        [ 43, 580, 730],
#        [510, 690, 870]])
