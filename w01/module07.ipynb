# %%
import array

mylist = [1,2,3,4]
print(type(mylist))

myarray = array.array('f', mylist)
print(myarray)
# Out:
# <class 'list'>
# <class 'array.array'>
# array('f', [1.0, 2.0, 3.0, 4.0])

# %%
# containers
a = [1,2,3,4]
b = [[1,2,3],[4,5,6]]

tensor = [1,2,3,4]
t2 = [[1,2,3],[4,5,6]]

c = set()
c.add(1)
c.add(2)

h = {"a": 12, "b": [1,2,3,4]}
